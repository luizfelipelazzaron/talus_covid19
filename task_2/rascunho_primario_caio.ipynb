# %%
# aqui eu baixo as bibliotecas
# não necessariamente uso todas elas, mas eu já usei em algum projeto do kaggle alguma vez
# eu guardo todas pra caso eu precise, não faz mal um import a mais :D
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from IPython.display import SVG
from graphviz import Source
from sklearn.tree import export_graphviz
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
# aqui é o processo padrão
# baixa o dataset, dá uma olhada por cima com describe
df = pd.read_excel('dataset.xlsx')
df.head()
# Out:
#         Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0  44477f75e8169d2                    13               negative
# 1  126e9dd13932f68                    17               negative
# 2  a46b4402a0e5696                     8               negative
# 3  f7d619a94f97c45                     5               negative
# 4  d9e41465789c2b5                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Patient addmited to intensive care unit (1=yes, 0=no)  Hematocrit  \
# 0                                                  0             NaN
# 1                                                  0        0.236515
# 2                                                  0             NaN
# 3                                                  0             NaN
# 4                                                  0             NaN
#
#    Hemoglobin  Platelets  Mean platelet volume   ...  \
# 0         NaN        NaN                    NaN  ...
# 1    -0.02234  -0.517413               0.010677  ...
# 2         NaN        NaN                    NaN  ...
# 3         NaN        NaN                    NaN  ...
# 4         NaN        NaN                    NaN  ...
#
#    Hb saturation (arterial blood gases)  pCO2 (arterial blood gas analysis)  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
#
#    Base excess (arterial blood gas analysis)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    pH (arterial blood gas analysis)  Total CO2 (arterial blood gas analysis)  \
# 0                               NaN                                      NaN
# 1                               NaN                                      NaN
# 2                               NaN                                      NaN
# 3                               NaN                                      NaN
# 4                               NaN                                      NaN
#
#    HCO3 (arterial blood gas analysis)  pO2 (arterial blood gas analysis)  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
#
#    Arteiral Fio2  Phosphor  ctO2 (arterial blood gas analysis)
# 0            NaN       NaN                                 NaN
# 1            NaN       NaN                                 NaN
# 2            NaN       NaN                                 NaN
# 3            NaN       NaN                                 NaN
# 4            NaN       NaN                                 NaN
#
# [5 rows x 111 columns]

# %%
df.describe()
# Out:
#        Patient age quantile  Patient addmited to regular ward (1=yes, 0=no)  \
# count           5644.000000                                     5644.000000
# mean               9.318391                                        0.013997
# std                5.777903                                        0.117489
# min                0.000000                                        0.000000
# 25%                4.000000                                        0.000000
# 50%                9.000000                                        0.000000
# 75%               14.000000                                        0.000000
# max               19.000000                                        1.000000
#
#        Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# count                                        5644.000000
# mean                                            0.008859
# std                                             0.093713
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Patient addmited to intensive care unit (1=yes, 0=no)    Hematocrit  \
# count                                        5644.000000      6.030000e+02
# mean                                            0.007264     -2.186214e-09
# std                                             0.084929      1.000830e+00
# min                                             0.000000     -4.501420e+00
# 25%                                             0.000000     -5.188074e-01
# 50%                                             0.000000      5.340703e-02
# 75%                                             0.000000      7.171751e-01
# max                                             1.000000      2.662704e+00
#
#          Hemoglobin     Platelets  Mean platelet volume   Red blood Cells  \
# count  6.030000e+02  6.020000e+02           5.990000e+02     6.020000e+02
# mean  -1.601319e-08 -3.535004e-10           7.438142e-09     8.424447e-09
# std    1.000830e+00  1.000832e+00           1.000836e+00     1.000832e+00
# min   -4.345603e+00 -2.552426e+00          -2.457575e+00    -3.970608e+00
# 25%   -5.862439e-01 -6.053457e-01          -6.624832e-01    -5.679496e-01
# 50%    4.031596e-02 -1.217160e-01          -1.015171e-01     1.385207e-02
# 75%    7.295320e-01  5.314981e-01           6.838353e-01     6.661759e-01
# max    2.671868e+00  9.532034e+00           3.713052e+00     3.645706e+00
#
#         Lymphocytes  ...  Hb saturation (arterial blood gases)  \
# count  6.020000e+02  ...                          2.700000e+01
# mean  -7.866736e-09  ...                         -1.379737e-10
# std    1.000832e+00  ...                          1.019049e+00
# min   -1.865070e+00  ...                         -1.999560e+00
# 25%   -7.307069e-01  ...                         -1.122574e+00
# 50%   -1.426696e-02  ...                          2.677689e-01
# 75%    5.976919e-01  ...                          7.383496e-01
# max    3.764100e+00  ...                          1.337265e+00
#
#        pCO2 (arterial blood gas analysis)  \
# count                        2.700000e+01
# mean                         8.416397e-09
# std                          1.019049e+00
# min                         -1.244817e+00
# 25%                         -5.348102e-01
# 50%                         -2.120799e-01
# 75%                          2.305214e-02
# max                          3.236524e+00
#
#        Base excess (arterial blood gas analysis)  \
# count                               2.700000e+01
# mean                               -1.655685e-09
# std                                 1.019049e+00
# min                                -3.082674e+00
# 25%                                -3.308668e-01
# 50%                                -1.181667e-02
# 75%                                 6.661649e-01
# max                                 1.703078e+00
#
#        pH (arterial blood gas analysis)  \
# count                      2.700000e+01
# mean                       4.139211e-10
# std                        1.019049e+00
# min                       -3.568877e+00
# 25%                       -9.210583e-02
# 50%                        2.942021e-01
# 75%                        5.115003e-01
# max                        1.042674e+00
#
#        Total CO2 (arterial blood gas analysis)  \
# count                             2.700000e+01
# mean                             -7.472139e-09
# std                               1.019049e+00
# min                              -2.925618e+00
# 25%                              -5.117720e-01
# 50%                               7.743482e-02
# 75%                               4.385609e-01
# max                               1.940087e+00
#
#        HCO3 (arterial blood gas analysis)  pO2 (arterial blood gas analysis)  \
# count                        2.700000e+01                       2.700000e+01
# mean                         6.070843e-09                      -2.469729e-08
# std                          1.019049e+00                       1.019049e+00
# min                         -2.985592e+00                      -1.175907e+00
# 25%                         -5.397211e-01                      -8.169898e-01
# 50%                          5.633191e-02                      -1.599549e-01
# 75%                          5.085100e-01                       4.500090e-01
# max                          2.029471e+00                       2.205371e+00
#
#        Arteiral Fio2      Phosphor  ctO2 (arterial blood gas analysis)
# count   2.000000e+01  2.000000e+01                        2.700000e+01
# mean    4.656613e-09  6.332993e-09                        5.243001e-09
# std     1.025978e+00  1.025978e+00                        1.019049e+00
# min    -1.532932e+00 -1.480526e+00                       -2.900254e+00
# 25%    -1.214975e-01 -5.527296e-01                       -4.852787e-01
# 50%    -1.174366e-02 -1.381825e-01                        1.826928e-01
# 75%    -1.174366e-02  2.763648e-01                        5.937525e-01
# max     2.841856e+00  2.862350e+00                        1.826932e+00
#
# [8 rows x 74 columns]

# %%
for column in df.columns:
    df[str(column)].replace('not_done',np.NaN, inplace=True)

# %%
# dá pra ver que tem um monte de NaN
# então aqui eu vou ver quais colunas têm a maior porcentagem de NaNs
(df.isnull().sum() / df.shape[0]).sort_values(ascending=False).head(10)
# Out:
# Prothrombin time (PT), Activity       1.000000
# D-Dimer                               1.000000
# Mycoplasma pneumoniae                 1.000000
# Urine - Sugar                         1.000000
# Partial thromboplastin time (PTT)     1.000000
# Urine - Nitrite                       1.000000
# Fio2 (venous blood gas analysis)      0.999823
# Vitamin B12                           0.999468
# Lipase dosage                         0.998583
# Albumin                               0.997697
# dtype: float64

# %%
# tem coluna que não tem dado nenhum!
# sendo assim, vamos ver quantas colunas têm dados faltando
contain_null = (df.isnull().sum() != 0).index
len(contain_null)
# Out:
# 111

# %%
# é, todas elas têm dados faltando, pelo visto
# então eu vou filtrar aquelas que têm menos de 1 input e excluí-las
# talvez lá na frente seja bom excluir aquelas que têm menos de dois, três
# mas por padrão eu sempre começo excluindo aquelas que têm só uma entrada ou menos
criterion = 'SARS-Cov-2 exam result'
less_then_one_input = []
for col in contain_null:
    num_input = df[df[col].notnull()][criterion].nunique()
    if num_input <= 1:
        less_then_one_input.append(col)
less_then_one_input
# Out:
# ['Mycoplasma pneumoniae',
#  'Fio2 (venous blood gas analysis)',
#  'Urine - Nitrite',
#  'Urine - Sugar',
#  'Partial thromboplastin time\xa0(PTT)\xa0',
#  'Prothrombin time (PT), Activity',
#  'Vitamin B12',
#  'D-Dimer',
#  'Albumin']

# %%
df.drop(less_then_one_input, axis=1, inplace=True)
df.head()
# Out:
#         Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0  44477f75e8169d2                    13               negative
# 1  126e9dd13932f68                    17               negative
# 2  a46b4402a0e5696                     8               negative
# 3  f7d619a94f97c45                     5               negative
# 4  d9e41465789c2b5                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Patient addmited to intensive care unit (1=yes, 0=no)  Hematocrit  \
# 0                                                  0             NaN
# 1                                                  0        0.236515
# 2                                                  0             NaN
# 3                                                  0             NaN
# 4                                                  0             NaN
#
#    Hemoglobin  Platelets  Mean platelet volume   ...  \
# 0         NaN        NaN                    NaN  ...
# 1    -0.02234  -0.517413               0.010677  ...
# 2         NaN        NaN                    NaN  ...
# 3         NaN        NaN                    NaN  ...
# 4         NaN        NaN                    NaN  ...
#
#    Hb saturation (arterial blood gases)  pCO2 (arterial blood gas analysis)  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
#
#    Base excess (arterial blood gas analysis)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    pH (arterial blood gas analysis)  Total CO2 (arterial blood gas analysis)  \
# 0                               NaN                                      NaN
# 1                               NaN                                      NaN
# 2                               NaN                                      NaN
# 3                               NaN                                      NaN
# 4                               NaN                                      NaN
#
#    HCO3 (arterial blood gas analysis)  pO2 (arterial blood gas analysis)  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
#
#    Arteiral Fio2  Phosphor  ctO2 (arterial blood gas analysis)
# 0            NaN       NaN                                 NaN
# 1            NaN       NaN                                 NaN
# 2            NaN       NaN                                 NaN
# 3            NaN       NaN                                 NaN
# 4            NaN       NaN                                 NaN
#
# [5 rows x 102 columns]

# %%
# é bom deixar todos os dados numéricos
# o computador interpreta melhor features numéricas
# vou fazer aqui de um jeito que entendam minhas transformações
categories_object = df.dtypes[df.dtypes == object].index
categories_object = categories_object.tolist()
categories_object.remove('Patient ID')
categories_object
# Out:
# ['SARS-Cov-2 exam result',
#  'Respiratory Syncytial Virus',
#  'Influenza A',
#  'Influenza B',
#  'Parainfluenza 1',
#  'CoronavirusNL63',
#  'Rhinovirus/Enterovirus',
#  'Coronavirus HKU1',
#  'Parainfluenza 3',
#  'Chlamydophila pneumoniae',
#  'Adenovirus',
#  'Parainfluenza 4',
#  'Coronavirus229E',
#  'CoronavirusOC43',
#  'Inf A H1N1 2009',
#  'Bordetella pertussis',
#  'Metapneumovirus',
#  'Parainfluenza 2',
#  'Influenza B, rapid test',
#  'Influenza A, rapid test',
#  'Strepto A',
#  'Urine - Esterase',
#  'Urine - Aspect',
#  'Urine - pH',
#  'Urine - Hemoglobin',
#  'Urine - Bile pigments',
#  'Urine - Ketone Bodies',
#  'Urine - Urobilinogen',
#  'Urine - Protein',
#  'Urine - Leukocytes',
#  'Urine - Crystals',
#  'Urine - Hyaline cylinders',
#  'Urine - Granular cylinders',
#  'Urine - Yeasts',
#  'Urine - Color']

# %%
for category in categories_object:
    df_category = df[category].astype('category')
    print(category + ':')
    print(df_category.cat.categories)
# Out:
# SARS-Cov-2 exam result:
# Index(['negative', 'positive'], dtype='object')
# Respiratory Syncytial Virus:
# Index(['detected', 'not_detected'], dtype='object')
# Influenza A:
# Index(['detected', 'not_detected'], dtype='object')
# Influenza B:
# Index(['detected', 'not_detected'], dtype='object')
# Parainfluenza 1:
# Index(['detected', 'not_detected'], dtype='object')
# CoronavirusNL63:
# Index(['detected', 'not_detected'], dtype='object')
# Rhinovirus/Enterovirus:
# Index(['detected', 'not_detected'], dtype='object')
# Coronavirus HKU1:
# Index(['detected', 'not_detected'], dtype='object')
# Parainfluenza 3:
# Index(['detected', 'not_detected'], dtype='object')
# Chlamydophila pneumoniae:
# Index(['detected', 'not_detected'], dtype='object')
# Adenovirus:
# Index(['detected', 'not_detected'], dtype='object')
# Parainfluenza 4:
# Index(['detected', 'not_detected'], dtype='object')
# Coronavirus229E:
# Index(['detected', 'not_detected'], dtype='object')
# CoronavirusOC43:
# Index(['detected', 'not_detected'], dtype='object')
# Inf A H1N1 2009:
# Index(['detected', 'not_detected'], dtype='object')
# Bordetella pertussis:
# Index(['detected', 'not_detected'], dtype='object')
# Metapneumovirus:
# Index(['detected', 'not_detected'], dtype='object')
# Parainfluenza 2:
# Index(['not_detected'], dtype='object')
# Influenza B, rapid test:
# Index(['negative', 'positive'], dtype='object')
# Influenza A, rapid test:
# Index(['negative', 'positive'], dtype='object')
# Strepto A:
# Index(['negative', 'positive'], dtype='object')
# Urine - Esterase:
# Index(['absent'], dtype='object')
# Urine - Aspect:
# Index(['altered_coloring', 'clear', 'cloudy', 'lightly_cloudy'], dtype='object')
# Urine - pH:
# Index([              5,             5.5,               6,             6.5,
#                      7,             '5',           '5.0',           '5.5',
#                    '6',           '6.0',           '6.5',           '7.0',
#                  '7.5',           '8.0', 'Não Realizado'],
#       dtype='object')
# Urine - Hemoglobin:
# Index(['absent', 'present'], dtype='object')
# Urine - Bile pigments:
# Index(['absent'], dtype='object')
# Urine - Ketone Bodies:
# Index(['absent'], dtype='object')
# Urine - Urobilinogen:
# Index(['normal'], dtype='object')
# Urine - Protein:
# Index(['absent'], dtype='object')
# Urine - Leukocytes:
# Index(['1000', '10000', '10600', '124000', '16000', '19000', '2000', '22000',
#        '229000', '23000', '2500', '2600', '28000', '29000', '3000', '32000',
#        '3310000', '38000', '4000', '40000', '43000', '4600', '5000', '5300',
#        '5942000', '6000', '624000', '7000', '77000', '8000', '<1000'],
#       dtype='object')
# Urine - Crystals:
# Index(['Ausentes', 'Oxalato de Cálcio +++', 'Oxalato de Cálcio -++',
#        'Urato Amorfo +++', 'Urato Amorfo --+'],
#       dtype='object')
# Urine - Hyaline cylinders:
# Index(['absent'], dtype='object')
# Urine - Granular cylinders:
# Index(['absent'], dtype='object')
# Urine - Yeasts:
# Index(['absent'], dtype='object')
# Urine - Color:
# Index(['citrus_yellow', 'light_yellow', 'orange', 'yellow'], dtype='object')

# %%
# isso é demorado
# vocês aí que terminaram cdados sabem um jeito mais fácil?
df = df.replace({'positive':1,'negative':0})
df = df.replace({'detected':1,'not_detected':0})
df = df.replace({'not_done': 0, 'absent': 1, 'present': 2})
df = df.replace({'altered_coloring':0,'clear':1,'cloudy':2,'lightly_cloudy':3})
df = df.replace({'normal': 1})
df = df.replace({'light_yellow': 1, 'yellow': 2, 'citrus_yellow': 3, 'orange': 4})
df = df.replace({'Não Realizado': 0})
df = df.replace({'<1000': 1000})
df = df.replace({'Ausentes': 1, 'Urato Amorfo --+': 0, 'Oxalato de Cálcio +++': 0, 'Oxalato de Cálcio -++': 0, 'Urato Amorfo +++': 0})
# rodando a célula de novo
# tinha esquecido de transformar esses caras em float
# não esqueçam isso, crianças
# o computador fica muito irritado se ele ver um número se dizendo de string
df['Urine - pH'] = df['Urine - pH'].astype('float')
df['Urine - Leukocytes'] = df['Urine - Leukocytes'].astype('float')

# %%
# já que a gente só tem um dataset eu mesmo vou criar um de treino e teste
from sklearn.model_selection import train_test_split
# nostalgia do hands-on...
# vou usar até o mesmo random_state do ageron
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train
# Out:
#            Patient ID  Patient age quantile  SARS-Cov-2 exam result  \
# 4680  5ae49b7c4583a5f                     9                       1
# 2330  42f9a21872c655f                    17                       0
# 2388  78df291478c439a                    14                       0
# 1657  51d9f4f0d6a1c71                     0                       0
# 1926  9b3ac6abc56b4d5                     4                       0
# ...               ...                   ...                     ...
# 3772  5159a43da3193e9                    12                       0
# 5191  aa1a5aa2441bc13                    19                       0
# 5226  482a960eb07d3cd                    16                       1
# 5390  d50b6f40b4545b3                     8                       0
# 860   749c510e7648661                     4                       0
#
#       Patient addmited to regular ward (1=yes, 0=no)  \
# 4680                                               0
# 2330                                               0
# 2388                                               0
# 1657                                               0
# 1926                                               0
# ...                                              ...
# 3772                                               0
# 5191                                               0
# 5226                                               0
# 5390                                               0
# 860                                                0
#
#       Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 4680                                                  0
# 2330                                                  0
# 2388                                                  0
# 1657                                                  0
# 1926                                                  0
# ...                                                 ...
# 3772                                                  0
# 5191                                                  0
# 5226                                                  0
# 5390                                                  0
# 860                                                   0
#
#       Patient addmited to intensive care unit (1=yes, 0=no)  Hematocrit  \
# 4680                                                  0        0.900284
# 2330                                                  0             NaN
# 2388                                                  0             NaN
# 1657                                                  0             NaN
# 1926                                                  0             NaN
# ...                                                 ...             ...
# 3772                                                  0             NaN
# 5191                                                  0             NaN
# 5226                                                  1       -0.427254
# 5390                                                  0             NaN
# 860                                                   0             NaN
#
#       Hemoglobin  Platelets  Mean platelet volume   ...  \
# 4680    1.105468  -0.605346               0.683835  ...
# 2330         NaN        NaN                    NaN  ...
# 2388         NaN        NaN                    NaN  ...
# 1657         NaN        NaN                    NaN  ...
# 1926         NaN        NaN                    NaN  ...
# ...          ...        ...                    ...  ...
# 3772         NaN        NaN                    NaN  ...
# 5191         NaN        NaN                    NaN  ...
# 5226   -0.210308  -1.271122              -0.325903  ...
# 5390         NaN        NaN                    NaN  ...
# 860          NaN        NaN                    NaN  ...
#
#       Hb saturation (arterial blood gases)  \
# 4680                                   NaN
# 2330                                   NaN
# 2388                                   NaN
# 1657                                   NaN
# 1926                                   NaN
# ...                                    ...
# 3772                                   NaN
# 5191                                   NaN
# 5226                              1.294485
# 5390                                   NaN
# 860                                    NaN
#
#       pCO2 (arterial blood gas analysis)  \
# 4680                                 NaN
# 2330                                 NaN
# 2388                                 NaN
# 1657                                 NaN
# 1926                                 NaN
# ...                                  ...
# 3772                                 NaN
# 5191                                 NaN
# 5226                           -0.138313
# 5390                                 NaN
# 860                                  NaN
#
#       Base excess (arterial blood gas analysis)  \
# 4680                                        NaN
# 2330                                        NaN
# 2388                                        NaN
# 1657                                        NaN
# 1926                                        NaN
# ...                                         ...
# 3772                                        NaN
# 5191                                        NaN
# 5226                                   0.666165
# 5390                                        NaN
# 860                                         NaN
#
#       pH (arterial blood gas analysis)  \
# 4680                               NaN
# 2330                               NaN
# 2388                               NaN
# 1657                               NaN
# 1926                               NaN
# ...                                ...
# 3772                               NaN
# 5191                               NaN
# 5226                          0.342491
# 5390                               NaN
# 860                                NaN
#
#       Total CO2 (arterial blood gas analysis)  \
# 4680                                      NaN
# 2330                                      NaN
# 2388                                      NaN
# 1657                                      NaN
# 1926                                      NaN
# ...                                       ...
# 3772                                      NaN
# 5191                                      NaN
# 5226                                 0.495581
# 5390                                      NaN
# 860                                       NaN
#
#       HCO3 (arterial blood gas analysis)  pO2 (arterial blood gas analysis)  \
# 4680                                 NaN                                NaN
# 2330                                 NaN                                NaN
# 2388                                 NaN                                NaN
# 1657                                 NaN                                NaN
# 1926                                 NaN                                NaN
# ...                                  ...                                ...
# 3772                                 NaN                                NaN
# 5191                                 NaN                                NaN
# 5226                            0.549617                           2.087693
# 5390                                 NaN                                NaN
# 860                                  NaN                                NaN
#
#       Arteiral Fio2  Phosphor  ctO2 (arterial blood gas analysis)
# 4680            NaN       NaN                                 NaN
# 2330            NaN       NaN                                 NaN
# 2388            NaN       NaN                                 NaN
# 1657            NaN       NaN                                 NaN
# 1926            NaN       NaN                                 NaN
# ...             ...       ...                                 ...
# 3772            NaN       NaN                                 NaN
# 5191            NaN       NaN                                 NaN
# 5226      -1.475128       NaN                            0.182693
# 5390            NaN       NaN                                 NaN
# 860             NaN       NaN                                 NaN
#
# [4515 rows x 102 columns]

# %%
df_test
# Out:
#            Patient ID  Patient age quantile  SARS-Cov-2 exam result  \
# 1694  5541f42a107f084                    17                       0
# 4434  d312238aa508c24                    14                       0
# 3297  23b19225d2fdd4c                     8                       0
# 3980  63aeba2b01cb895                     5                       0
# 4165  b90320c6c7bbb1e                     5                       0
# ...               ...                   ...                     ...
# 95    078780a7f821654                    18                       0
# 2445  460abf1fc98bbe4                     9                       0
# 842   08e04abcd2027c8                     8                       0
# 5015  b431d81c05626fa                     0                       0
# 2406  1c52085e86a9d23                    12                       0
#
#       Patient addmited to regular ward (1=yes, 0=no)  \
# 1694                                               0
# 4434                                               0
# 3297                                               0
# 3980                                               0
# 4165                                               0
# ...                                              ...
# 95                                                 0
# 2445                                               0
# 842                                                0
# 5015                                               0
# 2406                                               0
#
#       Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 1694                                                  0
# 4434                                                  0
# 3297                                                  0
# 3980                                                  0
# 4165                                                  0
# ...                                                 ...
# 95                                                    0
# 2445                                                  0
# 842                                                   0
# 5015                                                  0
# 2406                                                  0
#
#       Patient addmited to intensive care unit (1=yes, 0=no)  Hematocrit  \
# 1694                                                  0             NaN
# 4434                                                  0             NaN
# 3297                                                  0             NaN
# 3980                                                  0             NaN
# 4165                                                  0             NaN
# ...                                                 ...             ...
# 95                                                    0        0.946061
# 2445                                                  0       -0.473031
# 842                                                   0             NaN
# 5015                                                  1             NaN
# 2406                                                  0             NaN
#
#       Hemoglobin  Platelets  Mean platelet volume   ...  \
# 1694         NaN        NaN                    NaN  ...
# 4434         NaN        NaN                    NaN  ...
# 3297         NaN        NaN                    NaN  ...
# 3980         NaN        NaN                    NaN  ...
# 4165         NaN        NaN                    NaN  ...
# ...          ...        ...                    ...  ...
# 95      0.854844  -0.718402               0.908221  ...
# 2445   -0.774212   0.663397              -0.325903  ...
# 842          NaN        NaN                    NaN  ...
# 5015         NaN        NaN                    NaN  ...
# 2406         NaN        NaN                    NaN  ...
#
#       Hb saturation (arterial blood gases)  \
# 1694                                   NaN
# 4434                                   NaN
# 3297                                   NaN
# 3980                                   NaN
# 4165                                   NaN
# ...                                    ...
# 95                                     NaN
# 2445                                   NaN
# 842                                    NaN
# 5015                                   NaN
# 2406                                   NaN
#
#       pCO2 (arterial blood gas analysis)  \
# 1694                                 NaN
# 4434                                 NaN
# 3297                                 NaN
# 3980                                 NaN
# 4165                                 NaN
# ...                                  ...
# 95                                   NaN
# 2445                                 NaN
# 842                                  NaN
# 5015                                 NaN
# 2406                                 NaN
#
#       Base excess (arterial blood gas analysis)  \
# 1694                                        NaN
# 4434                                        NaN
# 3297                                        NaN
# 3980                                        NaN
# 4165                                        NaN
# ...                                         ...
# 95                                          NaN
# 2445                                        NaN
# 842                                         NaN
# 5015                                        NaN
# 2406                                        NaN
#
#       pH (arterial blood gas analysis)  \
# 1694                               NaN
# 4434                               NaN
# 3297                               NaN
# 3980                               NaN
# 4165                               NaN
# ...                                ...
# 95                                 NaN
# 2445                               NaN
# 842                                NaN
# 5015                               NaN
# 2406                               NaN
#
#       Total CO2 (arterial blood gas analysis)  \
# 1694                                      NaN
# 4434                                      NaN
# 3297                                      NaN
# 3980                                      NaN
# 4165                                      NaN
# ...                                       ...
# 95                                        NaN
# 2445                                      NaN
# 842                                       NaN
# 5015                                      NaN
# 2406                                      NaN
#
#       HCO3 (arterial blood gas analysis)  pO2 (arterial blood gas analysis)  \
# 1694                                 NaN                                NaN
# 4434                                 NaN                                NaN
# 3297                                 NaN                                NaN
# 3980                                 NaN                                NaN
# 4165                                 NaN                                NaN
# ...                                  ...                                ...
# 95                                   NaN                                NaN
# 2445                                 NaN                                NaN
# 842                                  NaN                                NaN
# 5015                                 NaN                                NaN
# 2406                                 NaN                                NaN
#
#       Arteiral Fio2  Phosphor  ctO2 (arterial blood gas analysis)
# 1694            NaN       NaN                                 NaN
# 4434            NaN       NaN                                 NaN
# 3297            NaN       NaN                                 NaN
# 3980            NaN       NaN                                 NaN
# 4165            NaN       NaN                                 NaN
# ...             ...       ...                                 ...
# 95              NaN       NaN                                 NaN
# 2445            NaN       NaN                                 NaN
# 842             NaN       NaN                                 NaN
# 5015            NaN       NaN                                 NaN
# 2406            NaN       NaN                                 NaN
#
# [1129 rows x 102 columns]

# %%
# nice! Agora eu só vou treinar o modelo
# X_train = df_train.drop(['Patient ID','Patient addmited to regular ward (1=yes, 0=no)',
#                         'Patient addmited to semi-intensive unit (1=yes, 0=no)',
#                         'Patient addmited to intensive care unit (1=yes, 0=no)'], axis=1)
# y_train = df_train.loc[:,['Patient addmited to regular ward (1=yes, 0=no)',
#                     'Patient addmited to semi-intensive unit (1=yes, 0=no)',
#                     'Patient addmited to intensive care unit (1=yes, 0=no)']]
X_train = df_train.drop(['Patient ID','SARS-Cov-2 exam result'], axis=1)
y_train = df_train['SARS-Cov-2 exam result']
# é bom dar um replace nos NaNs, o modelo não reconhece eles
# ao escolher um valor tão alto, o modelo reconhece que isso é um absurdo
X_train.fillna(99999, inplace=True)

# %%
# escolhi um decision tree de leve
# afinal ainda é terça... ? Talvez quarta, não sei. Quarentena
# deixa o random forest pra sexta a noite
# dia de perdição

# %%
# X_test = df_test.drop(['Patient ID','Patient addmited to regular ward (1=yes, 0=no)',
#                         'Patient addmited to semi-intensive unit (1=yes, 0=no)',
#                         'Patient addmited to intensive care unit (1=yes, 0=no)'], axis=1)
# y_test = df_test.loc[:,['Patient addmited to regular ward (1=yes, 0=no)',
#                     'Patient addmited to semi-intensive unit (1=yes, 0=no)',
#                     'Patient addmited to intensive care unit (1=yes, 0=no)']]
X_test = df_test.drop(['Patient ID','SARS-Cov-2 exam result'], axis=1)
y_test = df_test['SARS-Cov-2 exam result']
X_test.fillna(99999, inplace=True)

# %%
# agora é só eu fazer predições e tirar o erro e...
# mas é isso, vou pensar em jeitos de melhorar isso depois
from sklearn.metrics import f1_score,accuracy_score
from sklearn.ensemble import RandomForestClassifier,VotingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

rf = RandomForestClassifier(max_depth=5, random_state=42,n_estimators=100,class_weight = 'balanced')
rf.fit(X_train,y_train)
y_pred_rf = rf.predict(X_test)
print('accuracy:' , accuracy_score(y_pred_rf,y_test))
print('f1_score:' , f1_score(y_pred_rf,y_test,average='weighted'))
# Out:
# accuracy: 0.45969884853852966
# f1_score: 0.3668260140253131

# %% [markdown]
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRkuP6fPWcEx28NjiDYqSdZfBDNzePFqn4Uu_sKsOCyzwUHXSmX&usqp=CAU">
